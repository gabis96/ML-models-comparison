# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# scrape geo json from the web 
import requests
import json

def get_country_geojson(file_name, abreviation):
    url = f"https://geodata.ucdavis.edu/gadm/gadm4.1/json/gadm41_{abreviation}_0.json"
    r = requests.get(url)
    cont = r.json()
    with open(file_name, 'w') as outfile:
        outfile.write(json.dumps(cont))

# %% [markdown]
# ### Denmark

# %%
file = "../data/maps/denmark.json"
# get_country_geojson(file, 'DNK') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#87b7e0', aspect=None)
ax.set_axis_off()

# %% [markdown]
# ### Switzerland

# %%
file = "../data/maps/switzerland.json"
# get_country_geojson(file, 'CHE') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#2E75B2', aspect=None)
ax.set_axis_off()

# %% [markdown]
# ### Norway

# %%
file = "../data/maps/norway.json"
# get_country_geojson(file, 'NOR') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#215582')
ax.set_axis_off()

# %% [markdown]
# ### Finland

# %%
file = "../data/maps/finland.json"
# get_country_geojson(file, 'FIN') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#112A41')
ax.set_axis_off()

# %% [markdown]
# World

# %%
map_df = gpd.read_file("../data/shapefiles/World_Countries.shp")
ax = map_df.plot(color='#112A41')
ax.set_axis_off()

# %% [markdown]
# ### Afghanistan

# %%
file = "../data/maps/afghanistan.json"
# get_country_geojson(file) # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#112A41')
ax.set_axis_off()

# %% [markdown]
# ### South Sudan

# %%
file = "../data/maps/southsudan.json"
# get_country_geojson(file, 'SSD') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#112A41')
ax.set_axis_off()

# %% [markdown]
# ### Burundi

# %%
file = "../data/maps/burundi.json"
get_country_geojson(file, 'BDI') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#112A41')
ax.set_axis_off()

# %% [markdown]
# ### Togo

# %%
file = "../data/maps/togo.json"
# get_country_geojson(file, 'TGO') # already done
map_df = gpd.read_file(file)
ax = map_df.plot(color='#112A41')
ax.set_axis_off()

# %% [markdown]
# Wrold geometry with geopandas dataset 'naturalearth_lowres'

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world_country_data_map = {'Bosnia and Herz.':'Bosnia and Herzegovina','Congo':'Congo (Brazzaville)','Dem. Rep. Congo':'Congo (Kinshasa)','Czechia':'Czech Republic','Dominican Rep.':'Dominican Republic',"Côte d'Ivoire":'Ivory Coast','Mauritania':'Mauritius','Palestine':'Palestinian Territories','United States of America':'United States'}
# world['name'] = world['name'].apply(lambda x: world_country_data_map[x] if x in world_country_data_map else x)

# %%
world
# Out:
#                name                     geometry
# 0      Vatican City    POINT (12.45339 41.90328)
# 1        San Marino    POINT (12.44177 43.93610)
# 2             Vaduz     POINT (9.51667 47.13372)
# 3           Lobamba   POINT (31.20000 -26.46667)
# 4        Luxembourg     POINT (6.13000 49.61166)
# ..              ...                          ...
# 238  Rio de Janeiro  POINT (-43.21212 -22.90731)
# 239       São Paulo  POINT (-46.62697 -23.55673)
# 240          Sydney  POINT (151.21255 -33.87137)
# 241       Singapore    POINT (103.85387 1.29498)
# 242       Hong Kong   POINT (114.18306 22.30693)
#
# [243 rows x 2 columns]

# %%
world[world['name']=='Togo'].continent
# Out:
# 58    Africa
# Name: continent, dtype: object

# %%
world.continent.unique()
# Out:
# array(['Oceania', 'Africa', 'North America', 'Asia', 'South America',
#        'Europe', 'Seven seas (open ocean)', 'Antarctica'], dtype=object)
