# %% [markdown]
# ## Exploratory Data Analysis
#
# - Which countries have remained in the top 10 and bottom 10.
# - Which variables have higher impact in the Happiness Score.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed/WorldHappinees2015_2022')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Freedom                    1084 non-null   float64
#  1   Year                       1230 non-null   int64
#  2   Happiness Rank             1230 non-null   int64
#  3   Generosity                 1084 non-null   float64
#  4   Healthy life expectancy    1084 non-null   float64
#  5   Country                    1230 non-null   object
#  6   Perceptions of corruption  1083 non-null   float64
#  7   GDP per capita             1084 non-null   float64
#  8   Dystopia Residual          772 non-null    float64
#  9   Social support             614 non-null    float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 96.2+ KB

# %%
sns.set(style="ticks")
g = sns.pairplot(df, kind="reg")
